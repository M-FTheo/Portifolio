# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) Seu código aqui
assuntos = [df_mat,df_por,df_geo,df_ing,df_his,df_fis,df_qui]
for assunto in assuntos:
    print(assunto['Qt_acertos'].sum()/2400)
# Out:
# 0.49375
# 0.30125
# 0.14
# 0.15875
# 0.15
# 0.22166666666666668
# 0.22625

# %%
# 2) Seu código aqui
from functools import reduce
df_tot=reduce(lambda x,y:x+y, assuntos)
df_tot[['Qt_acertos']]
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Seu código aqui
for assunto in assuntos:
    assunto['percentual']=100*round(assunto['Qt_acertos']/24, 2)
# Out:
#     Qt_acertos  percentual
# 0            7        29.0
# 1           10        42.0
# 2           16        67.0
# 3            7        29.0
# 4            2         8.0
# ..         ...         ...
# 95           4        17.0
# 96           1         4.0
# 97           5        21.0
# 98          10        42.0
# 99          15        62.0
#
# [100 rows x 2 columns]

# %%
# 4) Seu código aqui
seg_fase = df_tot[df_tot['Qt_acertos']>45]
seg_fase[['Qt_acertos']].shape
# Out:
# (31, 1)

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
assuntos_rep = [df_mat, df_fis, df_qui]
assuntos_nome = ['df_mat', 'df_fis', 'df_qui']
for assunto in assuntos_nome:
    print (assunto)
for assunto in assuntos_rep:
    print(assunto[assunto['Qt_acertos']>0].shape[0])
# Out:
# df_mat
# df_fis
# df_qui
# 97
# 88
# 91

# %%
df_apr=df_tot.copy()
for assunto in assuntos_rep:
    df_apr += assunto[assunto['Qt_acertos']>0]

df_apr = df_apr.dropna(subset='Qt_acertos')

aprovados = df_apr.shape[0]

aprovados
# Out:
# 77

# %%
df_total= df_tot.copy()
df_total['mat']=df_mat['Qt_acertos']
df_total['fis']=df_fis['Qt_acertos']
df_total['qui']=df_qui['Qt_acertos']
df_total
# Out:
#     Qt_acertos  percentual  mat  fis  qui
# 0           35       144.0    6    8    3
# 1           48       200.0   19   11    8
# 2           50       209.0   14    4    4
# 3           32       133.0   10    0    8
# 4           30       124.0    7    9    3
# ..         ...         ...  ...  ...  ...
# 95          34       142.0    6    9    3
# 96          27       112.0    8    4    3
# 97          40       167.0   23    1    5
# 98          40       167.0    0   10   11
# 99          42       174.0   11    7    2
#
# [100 rows x 5 columns]

# %% [markdown]
# **Resposta 1 e 2**

# %%
df_repro = df_mat[df_mat['Qt_acertos']==0] + df_fis[df_fis['Qt_acertos']==0] + df_qui[df_qui['Qt_acertos']==0]
df_repro['Qt_acertos']=0
df_repro['percentual']=0
df_repro.shape, df_repro[['Qt_acertos']]
# Out:
# ((23, 2),
#      Qt_acertos
#  3            0
#  6            0
#  10           0
#  12           0
#  14           0
#  20           0
#  25           0
#  26           0
#  27           0
#  33           0
#  35           0
#  49           0
#  56           0
#  65           0
#  66           0
#  72           0
#  73           0
#  74           0
#  84           0
#  89           0
#  92           0
#  94           0
#  98           0)

# %% [markdown]
# **Respostas 3**

# %%
# seu código aqui
df_repro['his']=df_his['Qt_acertos']
df_repro['geo']=df_geo['Qt_acertos']
df_repro['his'].mean() , df_repro['geo'].mean()
print (f'Média Geo {df_repro['geo'].mean()}   Média His {df_repro['his'].mean()}')
# Out:
# Média Geo 3.217391304347826   Média His 3.4347826086956523

# %% [markdown]
# **Resposta 4**

# %%
assuntos_novo = [df_por,df_geo,df_ing,df_his]
df_tot_novo=reduce(lambda x,y:x+y, assuntos_novo)

df_apro = df_mat[df_mat['Qt_acertos']>0] + df_fis[df_fis['Qt_acertos']>0] + df_qui[df_qui['Qt_acertos']>0] + df_tot_novo
df_apro.dropna(inplace=True)
df_apro[df_apro['Qt_acertos']>45].shape
# Out:
# (26, 2)

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-b4de4043-acda-4a2e-9a9e-2afb98636f6a.c000.csv'

pd.set_option('display.max_columns', 100)
df.head()
# Out:
#                                  document_id  \
# 0  e9b5c1d8-471f-400c-9c3b-2db45ce4b1be-i0b0
# 1  dd097975-d896-4adc-97a1-5de3f51792a4-i0b0
# 2  d60011fe-a1b4-4d34-945e-8e041d420609-i0b0
# 3  dd180d26-5bee-44d5-a4d5-ea314976d7f1-i0b0
# 4  fdceed25-e60f-4635-9fe0-07f107916153-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  1b5a54c96f4fef5ba65535e12cb92502e98f7bd96a31a1...              39
# 1  5310f2da2074b4d20620f811323a6f7c4fc8853fc5a41f...              22
# 2  b26582744d70ed052c62fe4d535cdddb2a39159e39bf11...              20
# 3  d0a264fe07e8b95225c45d61cd6f1c020c1dec5d5f1125...              68
# 4  38e9546044dc852ffe5a450f463131beb05b5e077e5324...              60
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1983-05-08                          F                        4
# 1              1998-08-09                          F                       99
# ...

# %%
# 1) Sua solução aqui
df = pd.read_csv(arquivo, sep=';', decimal=',')
f'{df.shape[0]} foram registradas'
# Out:
# '390911 foram registradas'

# %%
# 2)
f'Um total de {df['paciente_id'].nunique()}'
# Out:
# 'Um total de 318850'

# %%
# 3) 
df_1d = df['paciente_id'].unique()
df_1d = df.loc[df['vacina_descricao_dose']=='1ª Dose']
f'Um total de {df_1d.shape[0] }'
# Out:
# 'Um total de 144117'

# %%
# 3) solução alternativa
f'Um total de {df[df['vacina_descricao_dose']=='1ª Dose'].shape[0]}'
# Out:
# 'Um total de 144117'

# %%
# 4)
f'Um total de {df[df['paciente_idade']<18].shape[0]}'
# Out:
# 'Um total de 79220'

# %%
# 5)

f'Foi um total de {df['estabelecimento_valor'].nunique()} '
# Out:
# 'Foi um total de 229 '

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
# 1)
df_novo=df.copy()
df_novo=df[df['paciente_idade']<18]
df_novo = df_novo[['estabelecimento_valor','estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']]
contagem_nomes = df_novo['estabelecimento_valor'].value_counts()
df_novo['qtd_vacinas'] = df_novo['estabelecimento_valor'].map(contagem_nomes)
df_novo
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 8                     6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 20                    7247435                PREFEITURA MUNICIPAL DE SAUDE
# 24                     924490                PREFEITURA MUNICIPAL DE FEIJO
# 40                    2002922                SECRETARIA MUNICIPAL DE SAUDE
# ...                       ...                                          ...
# 390888                3015548           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390897                2002914      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 390902                7014147                PREFEITURA MUNICIPAL DE FEIJO
# 390904                6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390910                2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
#
#                                  estalecimento_noFantasia  \
# ...

# %%
# 2)
df_novo_col=df.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)
df_novo['vacina_categoria_nome'].nunique()
# Out:
# array(['Trabalhadores de Saúde', 'Faixa Etária',
#        'Povos e Comunidades Tradicionais', 'Gestantes', nan,
#        'Trabalhadores da Educação', 'Povos Indígenas', 'Comorbidades',
#        'Trabalhadores Industriais',
#        'Pessoas de 60 anos ou mais institucionalizadas', 'Outros',
#        'Pessoas com Deficiência', 'Forças de Segurança e Salvamento',
#        'Trabalhadores de Transporte',
#        'Funcionário do Sistema de Privação de Liberdade',
#        'Pessoas em Situação de Rua', 'População Privada de Liberdade',
#        'Forças Armadas (membros ativos)',
#        'Trabalhadores de Limpeza Urbana', 'Puérperas',
#        'Pessoas Institucionalizadas', 'Trabalhadores Portuários'],
#       dtype=object)

# %%
# 4)
lista=[]
for item in df_novo.columns:
    lista.append(item)
lista
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaoSocial',
#  'estalecimento_noFantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf',
#  'qtd_vacinas']

# %%
# 5) Visto que todos os dados já foram processados na primeira etapa do exercício
df_novo.loc[:, :]
# Out:
#         estabelecimento_valor                  estabelecimento_razaoSocial  \
# 8                     6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349            PREFEITURA MUNICIPAL DE BRASILEIA
# 20                    7247435                PREFEITURA MUNICIPAL DE SAUDE
# 24                     924490                PREFEITURA MUNICIPAL DE FEIJO
# 40                    2002922                SECRETARIA MUNICIPAL DE SAUDE
# ...                       ...                                          ...
# 390888                3015548           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390897                2002914      PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 390902                7014147                PREFEITURA MUNICIPAL DE FEIJO
# 390904                6917291           PREFEITURA MUNICIPAL DE RIO BRANCO
# 390910                2001772  PREFEITURA MUNICIPAL DE SANTA ROSA DO PURUS
#
#                                  estalecimento_noFantasia  \
# ...

# %%
df_est = df_novo.drop_duplicates()
df_est
# Out:
#         estabelecimento_valor                 estabelecimento_razaoSocial  \
# 8                     6917291          PREFEITURA MUNICIPAL DE RIO BRANCO
# 19                    2001349           PREFEITURA MUNICIPAL DE BRASILEIA
# 20                    7247435               PREFEITURA MUNICIPAL DE SAUDE
# 24                     924490               PREFEITURA MUNICIPAL DE FEIJO
# 40                    2002922               SECRETARIA MUNICIPAL DE SAUDE
# ...                       ...                                         ...
# 205380                2001357  SECRETARIA MUNICIPAL DE SAUDE DE BRASILEIA
# 240642                4646770                           USF SAO FRANCISCO
# 339257                6411312   PREFEITURA MUNICIPAL DE PLACIDO DE CASTRO
# 357205                2000814       SECRETARIA DE ESTADO DE SAUDE DO ACRE
# 370287                2832798      PREFEITURA MUNICIPAL DE EPITACIOLANDIA
#
#                                  estalecimento_noFantasia  \
# ...
